# %%
stack = [5,10,15,]
stack.pop()
stack.pop()
print(stack)
# Out:
# [5]

# %%
from collections import deque
queue = deque([1,2,3,4])
print(queue)
queue.append(5)
print(queue)
# Out:
# deque([1, 2, 3, 4])
# deque([1, 2, 3, 4, 5])

# %%
 # Given dictionary
original_dict = {'a': 1, 'b': 2, 'c': 3, 'd': 4}

# Condition: Only include pairs where the value is greater than 2
new_dict = {key: value for key, value in original_dict.items() if value > 2}

print(original_dict.items())


for key, value in original_dict.items():
    if value > 2:
        new_dict[key] = value



# Print the new dictionary
print("New Dictionary:", new_dict)
# Out:
# dict_items([('a', 1), ('b', 2), ('c', 3), ('d', 4)])
# New Dictionary: {'c': 3, 'd': 4}

# %%
# 뒤집어진 dict 만들기 - key 와 value 를 바꾸기 value:key 형태로
original_dict = {'a': 1, 'b': 2, 'c': 3, 'd': 4}

reversed_dict = {value: key for key, value in original_dict.items()}

print("Reversed Dictionary:", reversed_dict)
# Out:
# Reversed Dictionary: {1: 'a', 2: 'b', 3: 'c', 4: 'd'}

# %%
fruit_prices = {
    'apple': 8,
    'banana': 12,
    'cherry': 15,
    'date': 5,
    'elderberry': 3,
    'fig': 20
}

# 가격이 10이상인 과일만 새로운 dictionary 에 넣기
